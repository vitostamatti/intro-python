# %% [markdown]
# - https://newsapi.org/
# - https://geocode.xyz/
# - https://restcountries.com/
# - https://api.openweathermap.org

# %%
import requests
import json
from urllib import parse
import pandas as pd

# %% [markdown]
# ## Countries

# %%
def get_countries():
    res = requests.get("https://restcountries.com/v3.1/all")
    return json.loads(res.content.decode())

countries_res = get_countries()

# %%
def expand_currency(df):
    return pd.concat(
            [df,pd.DataFrame(df.currency.tolist(), index=df.index, columns=['currency_key','currency_name',"currency_symbol"])]
        ,axis=1) 

def expand_timezones(df):
     tzdf = pd.DataFrame(df.timezones.tolist(), index=df.index)
     tzdf.columns = [f'timezone_{col+1}' for col in tzdf.columns]
     return pd.concat(
            [df,tzdf]
        ,axis=1)       

def expand_languages(df):
     lngdf = pd.DataFrame(df.languages.tolist(), index=df.index)
     lngdf.columns = [f'lang_{col+1}' for col in lngdf.columns]
     return pd.concat(
            [df,lngdf]
        ,axis=1)   

def process_countries_res(countries_res):
    countries = pd.DataFrame(countries_res)
    return (
        countries
        [[
            "name",
            "capital",
            "independent",
            "currencies",
            "continents",
            "latlng",
            "population",
            "region",
            "timezones",
            "area",
            "languages",
            "tld"
        ]]
        .assign(
            common_name = lambda df: df.name.apply(lambda x: x.get("common","")),
            oficial_name = lambda df: df.name.apply(lambda x: x.get("official","")),
            currency = lambda df: df.currencies.apply(
                                        lambda x: [
                                            list(x.keys())[0], 
                                            x.get(list(x.keys())[0]).get("name",""),
                                            x.get(list(x.keys())[0]).get("symbol","")
                                            ]
                                        if isinstance(x, dict) else []
                                    ),
            continents = lambda df: df.continents.apply(lambda x: x[0]),
            lat = lambda df: df.latlng.apply(lambda x: x[0]),
            lon = lambda df: df.latlng.apply(lambda x: x[1]),
            capital = lambda df: df.capital.apply(lambda x: x[0] if isinstance(x, list) else x),
            languages = lambda df: df.languages.apply(lambda x: [v for k,v in x.items()][:3] if isinstance(x, dict) else []),
            timezones = lambda df: df.timezones.apply(lambda x: x[:3] if isinstance(x, list) else []),
            country_code = lambda df: df.tld.apply(lambda x : x[0][1:] if isinstance(x, list) else pd.NA)
        )
        .pipe(
            expand_currency
        )
        .pipe(
            expand_timezones
        )
        .pipe(
            expand_languages
        )
        .drop(columns=['name','currencies','latlng','timezones','languages','currency','tld'])
    )

# %%
countries_clean = process_countries_res(countries_res)

# %%
countries_clean.to_csv(
     "../data/etl/countries.csv",
     index=False
)

# %% [markdown]
# ## News

# %%
NEWS_API_KEY = '35686b6ca73247b5a9f3a94c10e2e34d'
cc = [
'ae','ar','at','au','be',
'bg','br','ca','ch','cn',
'co','cu','cz','de',
'eg','fr','gb','gr',
'hk','hu','id','ie',
'il','in','it','jp',
'kr','lt','lv','ma',
'mx','my','ng','nl',
'no','nz','ph','pl',
'pt','ro','rs','ru',
'sa','se','sg','si',
'sk','th','tr','tw',
'ua','us','ve','za']

def get_news_by_country(country):
    news_url = f'https://newsapi.org/v2/top-headlines?country={country}&apiKey={NEWS_API_KEY}'
    res = requests.get(news_url)
    return json.loads(res.content.decode())

def process_news_res(news_res, country):
    news = pd.DataFrame(news_res['articles'])
    news['country_code'] = country
    news['source_id'] = news.source.apply(lambda x: x['id'])
    news['source_name'] = news.source.apply(lambda x: x['name'])
    return news.drop(columns=['source'])

# %%
news_data = []
for country in cc:
    news_res = get_news_by_country(country)
    news = process_news_res(news_res,country)
    news_data.append(news)

news_data = pd.concat(news_data)

# %%
news_data.head()

# %%
news_data.to_csv("../data/etl/news.csv", index=False)

# %%
def get_news_by_keyword(keyword):
    q = parse.quote(keyword)
    news_url = f'https://newsapi.org/v2/everything?q={q}&apiKey={NEWS_API_KEY}'
    res = requests.get(news_url)
    return json.loads(res.content.decode())

# %%
get_news_by_keyword("madrid")
# Out:
# {'status': 'ok',
#  'totalResults': 39340,
#  'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Flambé fire kills two in Madrid restaurant',
#    'description': 'Another ten people are injured after plastic plants caught fire as a waiter flambéed a dish.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-65360859',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/15CCE/production/_129449298_emergenciasmadrid.jpg',
#    'publishedAt': '2023-04-22T16:24:49Z',
#    'content': 'At least two people have died and another ten were injured after a waiter flambéed a dish, accidentally setting fire to an Italian restaurant on a busy Friday evening in Madrid. \r\nOne of the injured … [+1066 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Novak Djokovic has withdrawn from Madrid Open, say organisers',
#    'description': "World number one Novak Djokovic pulls out of next week's Madrid Open, the organisers say.",
#    'url': 'https://www.bbc.co.uk/sport/tennis/65360608',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/14234/production/_129448428_gettyimages-1251792268.jpg',
#    'publishedAt': '2023-04-22T14:04:05Z',
#    'content': "Novak Djokovic wore strapping on his right elbow during his defeat by Lorenzo Musetti at the Monte Carlo Masters earlier this month\r\nWorld number one Novak Djokovic has pulled out of next week's Madr… [+1007 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Statue mocking Spain's ex-king Juan Carlos appears in Madrid",
#    'description': 'The statue of the ex-king pointing a rifle at a sculpture of a bear mocks his love of hunting.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-65398280',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/DAFC/production/_129506065_gettyimages-1252188007.jpg',
#    'publishedAt': '2023-04-26T11:07:14Z',
#    'content': "A sculpture mocking Spain's former King Juan Carlos has appeared in Madrid's Puerta del Sol square. \r\nHe is shown aiming a rifle at a larger statue of a bear, an emblem of Madrid.\r\nJuan Carlos, who a… [+2116 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Real Madrid 2-0 Celta Vigo: Marco Asensio stars as Real win at home against Celta',
#    'description': 'Marco Asensio scores and assists for Real Madrid as they beat Celta Vigo in La Liga.',
#    'url': 'https://www.bbc.co.uk/sport/football/65360994',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/CC5B/production/_129451325_gettyimages-1484206524.jpg',
#    'publishedAt': '2023-04-22T21:06:58Z',
#    'content': 'Marco Asensio has scored eight goals for Real Madrid in 2023 in all competitions, more than any other Spanish player from the top five European leagues\r\nMarco Asensio scored one and made another as R… [+4187 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Real Madrid: Karim Benzema, Luka Modric and Toni Kroos to stay next season, says Carlo Ancelotti',
#    'description': 'Coach Carlo Ancelotti believes Karim Benzema, Luka Modric and Toni Kroos will stay with Real Madrid next season.',
#    'url': 'https://www.bbc.co.uk/sport/football/65214760',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/132A4/production/_129300587_gettyimages-893880884.jpg',
#    'publishedAt': '2023-04-07T15:57:53Z',
#    'content': "Toni Kroos, Karim Benzema and Luka Modric have 14 Champions League winners' medals between them\r\nCoach Carlo Ancelotti believes Karim Benzema, Luka Modric and Toni Kroos will stay with Real Madrid ne… [+1207 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Molly Taft',
#    'title': 'Rich People’s Swimming Pools Are Making Water Scarce',
#    'description': 'As the world gets warmer and droughts grip cities from Madrid to Shanghai, it can seem like we’re headed for a Mad Max-style future where water is a scarce resource. We’re already starting to see a version of this as regular Californians make water cuts while…',
#    'url': 'https://gizmodo.com/rich-people-s-swimming-pools-are-making-water-scarce-1850329294',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/976637b10e1fae57f85a571e561efdfd.jpg',
#    'publishedAt': '2023-04-12T19:52:00Z',
#    'content': 'As the world gets warmer and droughts grip cities from Madrid to Shanghai, it can seem like were headed for a Mad Max-style future where water is a scarce resource. Were already starting to see a ver… [+3711 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Rodrygo double eases Real Madrid into semi-finals - Reuters',
#    'description': 'Rodrygo double eases Real Madrid into semi-finals\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiY2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy9zb2NjZXIvcm9kcnlnby1kb3VibGUtZWFzZXMtcmVhbC1tYWRyaWQtaW50by1zZW1pLWZpbmFscy0yMDIzLTA0LTE4L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-18T21:00:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Morocco held to goalless draw by Peru in Madrid - Reuters.com',
#    'description': 'Morocco held to goalless draw by Peru in Madrid\xa0\xa0Reuters.com',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiXmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2xpZmVzdHlsZS9zcG9ydHMvbW9yb2Njby1oZWxkLWdvYWxsZXNzLWRyYXctYnktcGVydS1tYWRyaWQtMjAyMy0wMy0yOC_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-28T21:50:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Nadal to miss Madrid Open after recovery setback - Reuters',
#    'description': 'Nadal to miss Madrid Open after recovery setback\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiX2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy90ZW5uaXMvbmFkYWwtbWlzcy1tYWRyaWQtb3Blbi1hZnRlci1yZWNvdmVyeS1zZXRiYWNrLTIwMjMtMDQtMjAv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-20T09:42:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Alcaraz embracing the expectations at Madrid Open - Reuters',
#    'description': 'Alcaraz embracing the expectations at Madrid Open\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiXGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy90ZW5uaXMvYWxjYXJhei1lbWJyYWNpbmctZXhwZWN0YXRpb25zLW1hZHJpZC1vcGVuLTIwMjMtMDQtMjYv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-26T07:01:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Djokovic to miss Madrid Open say organisers - Reuters.com',
#    'description': 'Djokovic to miss Madrid Open say organisers\xa0\xa0Reuters.com',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiWmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy90ZW5uaXMvZGpva292aWMtbWlzcy1tYWRyaWQtb3Blbi1zYXktb3JnYW5pc2Vycy0yMDIzLTA0LTIyL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-22T13:17:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Holder Jabeur withdraws from Madrid Open with calf injury - Reuters',
#    'description': 'Holder Jabeur withdraws from Madrid Open with calf injury\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy90ZW5uaXMvaG9sZGVyLWphYmV1ci13aXRoZHJhd3MtbWFkcmlkLW9wZW4td2l0aC1jYWxmLWluanVyeS0yMDIzLTA0LTI0L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-24T20:28:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Pliskova withdraws from Madrid Open with knee injury - Reuters.com',
#    'description': 'Pliskova withdraws from Madrid Open with knee injury\xa0\xa0Reuters.com',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiWmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy9wbGlza292YS13aXRoZHJhd3MtbWFkcmlkLW9wZW4td2l0aC1rbmVlLWluanVyeS0yMDIzLTA0LTI0L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-24T06:37:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Two people killed, 10 hurt in Madrid restaurant blaze - Reuters.com',
#    'description': 'Two people killed, 10 hurt in Madrid restaurant blaze\xa0\xa0Reuters.com',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiYmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS90d28tcGVvcGxlLWtpbGxlZC0xMC1odXJ0LW1hZHJpZC1yZXN0YXVyYW50LWJsYXplLTIwMjMtMDQtMjIv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-22T07:37:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "Spain to exhume fascist movement founder's body from Madrid ... - Reuters",
#    'description': "Spain to exhume fascist movement founder's body from Madrid ...\xa0\xa0Reuters",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9zcGFpbi1leGh1bWUtZmFzY2lzdC1tb3ZlbWVudC1mb3VuZGVycy1ib2R5LW1hZHJpZC1tYXVzb2xldW0tMjAyMy0wNC0yNC_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-24T04:05:10Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "Courtois hopes Real Madrid won't regret not killing off Chelsea - Reuters",
#    'description': "Courtois hopes Real Madrid won't regret not killing off Chelsea\xa0\xa0Reuters",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMic2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL2xpZmVzdHlsZS9zcG9ydHMvY291cnRvaXMtaG9wZXMtcmVhbC1tYWRyaWQtd29udC1yZWdyZXQtbm90LWtpbGxpbmctb2ZmLWNoZWxzZWEtMjAyMy0wNC0xMi_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-12T22:47:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Real Madrid crash to Villarreal defeat as title chances fall further away - Reuters',
#    'description': 'Real Madrid crash to Villarreal defeat as title chances fall further away\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMieGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2xpZmVzdHlsZS9zcG9ydHMvcmVhbC1tYWRyaWQtY3Jhc2gtdmlsbGFycmVhbC1kZWZlYXQtdGl0bGUtY2hhbmNlcy1mYWxsLWZ1cnRoZXItYXdheS0yMDIzLTA0LTA4L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-08T21:28:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Bencic to skip Madrid, Rome events due to hip issue - Reuters',
#    'description': 'Bencic to skip Madrid, Rome events due to hip issue\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiXmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy90ZW5uaXMvYmVuY2ljLXNraXAtbWFkcmlkLXJvbWUtZXZlbnRzLWR1ZS1oaXAtaXNzdWUtMjAyMy0wNC0yMC_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-20T03:00:31Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Reuters',
#    'title': 'Ferran Torres gives Barcelona edge over Atlético Madrid as title draws closer',
#    'description': 'Ferran Torres struck late in the first half to earn Barcelona a 1-0 victory over third-placed Atlético Madrid at Camp Nou on Sunday.Victory helped the home side tighten their grip on top spot as they moved a step closer to their 27th La Liga title. With eight…',
#    'url': 'https://www.theguardian.com/football/2023/apr/23/barcelona-atletico-madrid-la-liga-match-report',
#    'urlToImage': 'https://i.guim.co.uk/img/media/27d811e41a469b50c2b8cbc7e55099d86b08fbc0/491_636_3828_2297/master/3828.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=06f895d52931ce68e2115ad12f388dae',
#    'publishedAt': '2023-04-23T17:56:13Z',
#    'content': 'Ferran Torres struck late in the first half to earn Barcelona a 1-0 victory over third-placed Atlético Madrid at Camp Nou on Sunday.\r\nVictory helped the home side tighten their grip on top spot as th… [+2987 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Sid Lowe at Camp Nou',
#    'title': 'Real Madrid put Barcelona to sword with Karim Benzema cup hat-trick',
#    'description': '• Frenchman to the fore in 4-0 drubbing at Camp Nou• Carlo Ancelotti’s team will meet Osasuna in finalThis time it’s our turn, Carlo Ancelotti had said, but even he couldn’t have imagined it would end up this good. Barcelona had won three clasicos in a row; b…',
#    'url': 'https://www.theguardian.com/football/2023/apr/05/real-madrid-put-barcelona-to-sword-with-karim-benzema-cup-hat-trick',
#    'urlToImage': 'https://i.guim.co.uk/img/media/96847b3bf682a41fe5f39b4b42d0617d6b8cc20c/0_429_6432_3859/master/6432.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=30e18fc002499f3761a484d9b2ba7e97',
#    'publishedAt': '2023-04-05T21:53:15Z',
#    'content': 'This time its our turn, Carlo Ancelotti had said, but even he couldnt have imagined it would end up this good. Barcelona had won three clasicos in a row; by the final minutes of the fourth, though, i… [+5974 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg at the Santiago Bernabéu',
#    'title': 'Real Madrid force Todd Boehly to eat his words after Chelsea win prediction | Jacob Steinberg',
#    'description': 'A beautiful piece of skill from Karim Benzema would have unnerved the American who may now regret his trash-talkingIf there was a moment to make Todd Boehly think twice about making such a bold prediction ever again, it came when Karim Benzema took a pass wit…',
#    'url': 'https://www.theguardian.com/football/blog/2023/apr/12/real-madrid-force-todd-boehly-to-eat-his-words-after-chelsea-win-prediction',
#    'urlToImage': 'https://i.guim.co.uk/img/media/9a3f570ddcc26366dd4728500d6812c9a4ad9242/114_332_3209_1925/master/3209.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=25b1d359f60757d15e99ae8da27b8fe1',
#    'publishedAt': '2023-04-12T22:48:54Z',
#    'content': 'If there was a moment to make Todd Boehly think twice about making such a bold prediction ever again, it came when Karim Benzema took a pass with his back to goal just before half-time and used the o… [+4990 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Associated Press',
#    'title': 'Antonio Rüdiger racially abused by fans after Real Madrid victory at Cádiz',
#    'description': '<ul><li>Video shows abuse aimed at defender after 2-0 victory</li><li>La Liga has been blighted by racial abuse this season</li></ul>The Real Madrid defender Antonio Rüdiger was racially abused by fans after the team’s La Liga game at Cádiz on Saturday evenin…',
#    'url': 'https://www.theguardian.com/football/2023/apr/16/antonio-rudiger-racially-abused-by-fans-cadiz-real-madrid-la-liga',
#    'urlToImage': 'https://i.guim.co.uk/img/media/561baea7b88bdab1e085b74f7b861d771fe93362/0_143_3424_2054/master/3424.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=15da50171758c1c148535eba53b829a9',
#    'publishedAt': '2023-04-16T13:28:53Z',
#    'content': 'The Real Madrid defender Antonio Rüdiger was racially abused by fans after the teams La Liga game at Cádiz on Saturday evening.\r\nVideo posted by Spanish media on Sunday showed Cádiz fans hurling abus… [+2378 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg',
#    'title': 'Do Chelsea have the leaders or quality to offer any fightback against Real Madrid?',
#    'description': 'Todd Boehly will hope criticism of his players can inspire a response as the Blues aim to overturn a two-goal deficitThe dust was still settling on Chelsea’s demoralising defeat by Brighton on Saturday when three of the club’s owners – Todd Boehly, Behdad Egh…',
#    'url': 'https://www.theguardian.com/football/2023/apr/18/chelsea-leaders-quality-champions-league-real-madrid-analysis',
#    'urlToImage': 'https://i.guim.co.uk/img/media/3971b7bab2c504c95ef0430579dd2e2d377ef11a/0_90_3299_1980/master/3299.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=e78be7ee5772f29932b90138889760ea',
#    'publishedAt': '2023-04-18T07:00:38Z',
#    'content': 'The dust was still settling on Chelseas demoralising defeat by Brighton on Saturday when three of the clubs owners Todd Boehly, Behdad Eghbali and Hansjörg Wyss walked into the home dressing room to … [+5070 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Rob Smyth',
#    'title': 'Barcelona v Real Madrid: Copa del Rey semi-final, second leg – live',
#    'description': '<ul><li>Updates from the 8pm BST kick-off at the Camp Nou</li><li>Live scoreboard: the latest from Wednesday’s games</li><li>Get in touch: you can mail Rob with your thoughts</li></ul>Pre-match listeningSo, Barcelona make four changes from their win at Elche …',
#    'url': 'https://www.theguardian.com/football/live/2023/apr/05/barcelona-v-real-madrid-copa-del-rey-semi-final-second-leg-live',
#    'urlToImage': 'https://i.guim.co.uk/img/media/fdd2c149317441c8e81690ed722f6fcf57c1705e/0_95_5907_3545/master/5907.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=39fa9924ff07a60d5789390dfbb01d42',
#    'publishedAt': '2023-04-05T18:16:40Z',
#    'content': 'So, Barcelona make four changes from their win at Elche on Saturday: Raphinha, Franck Kessie, Sergio Busquets and Alejandro Balde replace Ansu Fati, Eric Garcia, Jordi Alba and Ferran Torres.\r\nEduard… [+1658 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg in Madrid',
#    'title': 'Chelsea take up Madrid challenge hoping for Champions League miracle | Jacob Steinberg',
#    'description': 'Frank Lampard wants to emulate Roberto Di Matteo’s 2012 win but beating the kings of Europe is the toughest assignmentThey would have to call it The Miracle of Frank Lampard. It would be the barely plausible tale of the man who was guiding Everton into the Ch…',
#    'url': 'https://www.theguardian.com/football/2023/apr/12/chelsea-take-up-madrid-challenge-hoping-for-champions-league-miracle',
#    'urlToImage': 'https://i.guim.co.uk/img/media/8a1fe39e0c86a69513061f7d5a392fd0b140207e/0_150_4500_2700/master/4500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=aeecd3577b944dabc90ee881845d57d6',
#    'publishedAt': '2023-04-12T07:00:07Z',
#    'content': 'They would have to call it The Miracle of Frank Lampard. It would be the barely plausible tale of the man who was guiding Everton into the Championship landing a new job three months later and, in de… [+5781 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Daniel Gallan',
#    'title': 'Chelsea v Real Madrid: Champions League quarter-final, second leg – live',
#    'description': '<ul><li>Champions League quarter-final updates, 8pm BST kick-off</li><li>Napoli v Milan – live | And you email Daniel or tweet him</li></ul>It’s not going to happen, right? I mean we can all agree that this isn’t going to happen. Opta’s ‘Supercomputer’ (whate…',
#    'url': 'https://www.theguardian.com/football/live/2023/apr/18/chelsea-v-real-madrid-champions-league-quarter-final-second-leg-live-score-updates',
#    'urlToImage': 'https://i.guim.co.uk/img/media/a7b2bce4df78e0f3faad35ef390f2a8cfbd144ef/0_346_5184_3110/master/5184.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=93e4d4de2a83e7e99319c794a19b2e31',
#    'publishedAt': '2023-04-18T17:30:16Z',
#    'content': 'Show key events onlyPlease turn on JavaScript to use this feature\r\nOf course, as is so often the case with Chelsea, its not just the fate of a ball on our minds.\r\nThe Oligarch Files, as this sweeping… [+2702 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'David Hytner at Stamford Bridge',
#    'title': 'Chelsea toothless as Real Madrid move into Champions League semi-final',
#    'description': 'The pulse had been faint beforehand and, as expected, it was extinguished for Chelsea well before full-time, this Champions League quarter-final exit sounding the death knell for their season.Frank Lampard’s team had a go, bringing the hustle in the first-hal…',
#    'url': 'https://www.theguardian.com/football/2023/apr/18/chelsea-real-madrid-champions-league-quarter-final-second-leg-match-report',
#    'urlToImage': 'https://i.guim.co.uk/img/media/165913e25a41e1929c1b054b562af0de7fdae234/0_51_1904_1142/master/1904.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=f94d172412146d1664bd494b20f85a4f',
#    'publishedAt': '2023-04-18T21:01:32Z',
#    'content': 'The pulse had been faint beforehand and, as expected, it was extinguished for Chelsea well before full-time, this Champions League quarter-final exit sounding the death knell for their season.\r\nFrank… [+5283 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Scott Murray',
#    'title': 'Real Madrid v Chelsea: Champions League quarter-final, first leg – live',
#    'description': '<ul><li>Champions League updates from the 8pm BST kick-off</li><li>Milan v Napoli – live | And email your thoughts to Scott</li></ul>Quite a few Chelsea players need to be on their best behaviour this evening. Of the starting line-up, Kepa, Enzo Fernández, Th…',
#    'url': 'https://www.theguardian.com/football/live/2023/apr/12/real-madrid-v-chelsea-champions-league-quarter-final-first-leg-live-score-updates',
#    'urlToImage': 'https://i.guim.co.uk/img/media/a5fcc1ac2a6fcc745397daf029097fe9b5d4c6c4/0_0_2025_1215/master/2025.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=2a543ea7964f2d7f02feb6f0b55a5676',
#    'publishedAt': '2023-04-12T17:55:24Z',
#    'content': 'Show key events onlyPlease turn on JavaScript to use this feature\r\nThe pre-match mailbag doesnt make great reading for poor old Frank. Is it too early for the joke about Lamps is going out, all over … [+4646 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Sid Lowe at the Santiago Bernabéu',
#    'title': 'Benzema and Asensio win first leg for Real Madrid against 10-man Chelsea',
#    'description': 'Todd Boehly’s belief didn’t last long. Stopped outside the restaurant where directors from these two teams had lunch in the hours before this Champions League quarter-final first leg, the club’s owner had told Chelsea fans: “Have faith, we’re going to win 3-0…',
#    'url': 'https://www.theguardian.com/football/2023/apr/12/real-madrid-chelsea-champions-league-quarter-final-first-leg-match-report',
#    'urlToImage': 'https://i.guim.co.uk/img/media/a7f1b919d486620cab9c94d8e666fa2ce72290a0/246_84_2095_1258/master/2095.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=17a5d3dc20c770eb5a75c9701cc45682',
#    'publishedAt': '2023-04-12T21:00:26Z',
#    'content': 'Todd Boehlys belief didnt last long. Stopped outside the restaurant where directors from these two teams had lunch in the hours before this Champions League quarter-final first leg, the clubs owner h… [+5153 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'PA Media',
#    'title': 'Emma Raducanu forced out of Madrid Open by injury just before first match',
#    'description': '<ul><li>Briton was due to start her campaign against Viktoriya Tomova </li><li>The 2021 US Open champion will now drop out of world’s top 100 </li></ul>Emma Raducanu has withdrawn from the Madrid Open just hours before her first-round match because of an inju…',
#    'url': 'https://www.theguardian.com/sport/2023/apr/26/injury-forces-emma-raducanu-out-tennis-madrid-open-before-first-match',
#    'urlToImage': 'https://i.guim.co.uk/img/media/fbd40843810c8350e3ad94c40791df23afffd8bd/0_39_5000_3000/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=68edd153dc67b2d0a4173eb8375ed83e',
#    'publishedAt': '2023-04-26T10:59:53Z',
#    'content': 'Emma Raducanu has withdrawn from the Madrid Open just hours before her first-round match because of an injury to her right hand.\r\nRaducanu, who was due to start her campaign against the lucky loser V… [+263 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Brendan Griffiths',
#    'title': 'Where to watch Chelsea vs. Real Madrid live stream for free online',
#    'description': "Looking for a Champions League live stream tonight? We've got the latest options on how to watch Chelsea vs. Real Madrid online for free.",
#    'url': 'https://www.businessinsider.com/guides/streaming/where-to-watch-chelsea-vs-real-madrid-live-stream-free-2023-4',
#    'urlToImage': 'https://i.insider.com/6436848c2588f70018ce6668?width=1200&format=jpeg',
#    'publishedAt': '2023-04-18T16:51:29Z',
#    'content': "Getty/Angel Martinez\r\nWhen you buy through our links, Insider may earn an affiliate commission. Learn more.It's time for the second leg of the Champions League quarter-finals and we can help you find… [+4394 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Brendan Griffiths',
#    'title': 'Where to watch Real Madrid vs. Chelsea live stream for free online',
#    'description': "Looking for a Champions League live stream? We've got the latest options on how to watch Real Madrid vs. Chelsea online for free today from anywhere.",
#    'url': 'https://www.businessinsider.com/guides/streaming/where-to-watch-real-madrid-vs-chelsea-live-stream-free-2023-4',
#    'urlToImage': 'https://i.insider.com/6436848c2588f70018ce6668?width=1200&format=jpeg',
#    'publishedAt': '2023-04-12T11:11:26Z',
#    'content': 'Getty/Angel Martinez\r\nWhen you buy through our links, Insider may earn an affiliate commission. Learn more.We saw some great games in the first round of the Champions League quarter-finals last night… [+4567 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg in Madrid',
#    'title': 'Chelsea keep showing they are all promise and no substance | Jacob Steinberg',
#    'description': 'Timid display in Madrid yet another example of their expensive attack being confused and misshapenNot many visiting players are given a standing ovation at the Bernabéu. Ronaldinho got one after destroying Real Madrid for Barcelona in 2006 and Andrés Iniesta’…',
#    'url': 'https://www.theguardian.com/football/blog/2023/apr/13/chelsea-all-promise-no-substance',
#    'urlToImage': 'https://i.guim.co.uk/img/media/464eaea8c6097e246daa0caf5328c44b5b7833a3/0_136_2048_1229/master/2048.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=d28e2b89c7566995c2e47946dc95cbbf',
#    'publishedAt': '2023-04-13T12:27:11Z',
#    'content': 'Not many visiting players are given a standing ovation at the Bernabéu. Ronaldinho got one after destroying Real Madrid for Barcelona in 2006 and Andrés Iniestas greatness was recognised after a stun… [+5306 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Sam Jones in Madrid',
#    'title': 'Body of Spain’s fascist party founder to be removed from basilica',
#    'description': 'Family will rebury José Antonio Primo de Rivera in Madrid cemetery to pre-empt state exhumationNearly four years after Franco’s remains were removed from the hulking Valley of the Fallen mausoleum outside Madrid, those of José Antonio Primo de Rivera, the fou…',
#    'url': 'https://www.theguardian.com/world/2023/apr/23/body-of-spains-fascist-party-founder-to-be-removed-from-basilica',
#    'urlToImage': 'https://i.guim.co.uk/img/media/e02327f39e081711ef1f22cc87ade03169674d82/0_155_5000_2999/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=f7180de4b9f508603591ff79aca19f5a',
#    'publishedAt': '2023-04-23T16:28:32Z',
#    'content': 'Nearly four years after Francos remains were removed from the hulking Valley of the Fallen mausoleum outside Madrid, those of José Antonio Primo de Rivera, the founder of the Falangist party, are to … [+5497 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg at Stamford Bridge',
#    'title': 'Didier Drogba: ‘Chelsea now lacks class … I don’t recognise the club’',
#    'description': '<ul><li>Club legend launches stinging attack after Chelsea defeat</li><li>Real Madrid march on in Champions League with 2-0 win</li></ul>Didier Drogba has launched a stinging attack on Todd Boehly and Clearlake Capital, accusing Chelsea’s owners of lacking cl…',
#    'url': 'https://www.theguardian.com/football/2023/apr/18/didier-drogba-chelsea-now-lacks-class-i-dont-recognise-the-club',
#    'urlToImage': 'https://i.guim.co.uk/img/media/f9b06eb070b51747203264bff9e676b4a50d5e5b/0_0_4907_2944/master/4907.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=c83e2c04f6df8a23fe12c3988a4b4b7f',
#    'publishedAt': '2023-04-18T22:53:20Z',
#    'content': 'Didier Drogba has launched a stinging attack on Todd Boehly and Clearlake Capital, accusing Chelseas owners of lacking class and claiming that the club has become unrecognisable since being sold last… [+2555 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Guardian sport',
#    'title': 'Which manager had the highest win percentage when they were sacked? | The Knowledge',
#    'description': 'Plus: scorers hitting four or more but still losing and players to appear for champions and relegated sides in the same season<ul><li>Mail us your questions or tweet @TheKnowledge_GU</li></ul>“Julian Nagelsmann was sacked by Bayern Munich despite a win percen…',
#    'url': 'https://www.theguardian.com/football/2023/mar/29/which-manager-had-the-highest-win-percentage-when-they-were-sacked',
#    'urlToImage': 'https://i.guim.co.uk/img/media/283c66ee30f4609405aff964b578770565a45732/0_0_5000_3000/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9d43cbc7217d7fd6715ceef0012694e6',
#    'publishedAt': '2023-03-29T09:00:31Z',
#    'content': 'Julian Nagelsmann was sacked by Bayern Munich despite a win percentage of 71.4, says Oisin Hughes. With a minimum of, say, 10 games, is this a record?\r\nWhen, in 1990, that esteemed philosopher Robert… [+10321 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Sid Lowe in Madrid',
#    'title': 'Carlo Ancelotti sparkles as he offers sly reminder of Real Madrid’s quality',
#    'description': 'Before Chelsea’s visit, the manager smoothly sends a message to the doubters who put last season’s triumph down to luckCarlo Ancelotti had finished talking, or at least that’s what everyone thought, and Real Madrid’s press officer had started wrapping up the …',
#    'url': 'https://www.theguardian.com/football/2023/apr/11/carlo-ancelotti-real-madrid-quality-chelsea-champions-league',
#    'urlToImage': 'https://i.guim.co.uk/img/media/7a7dfdc0f80e7e51ebc2e8450cc09478f26c2ae8/972_879_7220_4332/master/7220.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=f2ca9ff4093eb7335ecfa84bddfe4421',
#    'publishedAt': '2023-04-11T17:05:52Z',
#    'content': 'Carlo Ancelotti had finished talking, or at least thats what everyone thought, and Real Madrids press officer had started wrapping up the final news conference before facing Chelsea when the coach su… [+5825 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg',
#    'title': 'Todd Boehly tells Chelsea squad season is ‘embarrassing’ in post-game speech',
#    'description': '<ul><li>Co-owner visits dressing room after defeat by Brighton</li><li>His aim was to motivate players before Real Madrid tie</li></ul>Todd Boehly attempted to rouse Chelsea’s players before Tuesday’s Champions League tie against Real Madrid by delivering a s…',
#    'url': 'https://www.theguardian.com/football/2023/apr/17/todd-boehly-tells-chelsea-season-embarrassing-dressing-room-brighton-real-madrid',
#    'urlToImage': 'https://i.guim.co.uk/img/media/33775584f14294872a9449c175f2d9af48d7e7e3/0_38_2824_1695/master/2824.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=7840dbcdb401838dc199840d8ed5def4',
#    'publishedAt': '2023-04-17T13:55:39Z',
#    'content': 'Todd Boehly attempted to rouse Chelseas players before Tuesdays Champions League tie against Real Madrid by delivering a speech in the dressing room after the defeat by Brighton on Saturday, during w… [+3378 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'The Associated Press',
#    'title': 'Djokovic to miss Madrid Open along with Nadal',
#    'description': 'The Madrid Open says that top-ranked Novak Djokovic will miss the Spanish tournament',
#    'url': 'https://abcnews.go.com/Sports/wireStory/djokovic-miss-madrid-open-nadal-98774112',
#    'urlToImage': 'https://s.abcnews.com/images/Sports/wirestory_c2f4696c7ed29f44e454703baecc94fe_12x5_992.jpg',
#    'publishedAt': '2023-04-22T13:47:31Z',
#    'content': 'MADRID -- Top-ranked Novak Djokovic will miss the Madrid Open, apparently due to a fitness issue, the Spanish event said Saturday.\r\nThe Madrid Open said on Twitter: Wishing you a speedy recovery, we … [+933 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'PA Media',
#    'title': '‘I don’t know’: Rafael Nadal admits hip injury may rule him out of French Open',
#    'description': '<ul><li>Muscle injury sustained in Australia has been slow to heal</li><li>Nadal misses Madrid Open to follow Monte Carlo and Barcelona</li></ul>Rafael Nadal is a major doubt for the French Open after admitting treatment on the hip injury he suffered in Janua…',
#    'url': 'https://www.theguardian.com/sport/2023/apr/20/i-dont-know-rafael-nadal-admits-hip-injury-may-rule-him-out-of-french-open',
#    'urlToImage': 'https://i.guim.co.uk/img/media/68daae723dfd4a1722f543db4186f6a89d844c1a/0_186_3800_2281/master/3800.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=fc2d4d3bff806fb73c908816b85e7b50',
#    'publishedAt': '2023-04-20T10:49:30Z',
#    'content': 'Rafael Nadal is a major doubt for the French Open after admitting treatment on the hip injury he suffered in January has not worked.\r\nThe 22-time grand slam champion had hoped the issue, which occurr… [+2000 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Barney Ronay at Stamford Bridge',
#    'title': 'Boehly’s Chelsea show the distorting effect of money without sense or love | Barney Ronay',
#    'description': 'Real Madrid just had to be good enough against opponents resembling a sinking vessel peopled by castawaysWell, there goes the season. Perhaps summer budget too. Who knows maybe the entire Chelsea 3.0 Blue Sky Project Stage One?With 28 minutes to go in a Champ…',
#    'url': 'https://www.theguardian.com/football/blog/2023/apr/18/chelsea-show-distorting-effect-of-money-without-sense-or-love',
#    'urlToImage': 'https://i.guim.co.uk/img/media/8a70629544e4c5b2eda65bb63c834d021f6d75b0/0_309_5281_3169/master/5281.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=3eaf17e726c92e599c786e934c968d1c',
#    'publishedAt': '2023-04-18T22:38:33Z',
#    'content': 'Well, there goes the season. Perhaps summer budget too. Who knows maybe the entire Chelsea 3.0 Blue Sky Project Stage One?\r\nWith 28 minutes to go in a Champions League second leg Chelsea always seeme… [+5718 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jonathan Wilson at Molineux',
#    'title': 'Lampard offers few fresh ideas as Chelsea endure new manager splat | Jonathan Wilson',
#    'description': 'Defeat at Wolves suggested that coach’s second coming will not provide an edge in the Champions League against Real MadridThe narrative seemed to write itself: Frank Lampard, having been offed by a famous Roman, resurrecting his managerial career at Easter. B…',
#    'url': 'https://www.theguardian.com/sport/blog/2023/apr/08/frank-lampard-offers-few-new-ideas-as-chelsea-suffer-new-manager-splat',
#    'urlToImage': 'https://i.guim.co.uk/img/media/8504b2f8e56571c02b8c5ecf0937f7ef8a3a2de6/0_155_3500_2101/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdG8tZGVmYXVsdC5wbmc&enable=upscale&s=5386e13fd7e88dc3edac74e0299eb56e',
#    'publishedAt': '2023-04-08T17:14:35Z',
#    'content': 'The narrative seemed to write itself: Frank Lampard, having been offed by a famous Roman, resurrecting his managerial career at Easter. But the narrative was wrong. There has been no new manager boun… [+5419 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jamie Jackson at the Allianz Arena',
#    'title': 'Haaland on target as Manchester City ease past Bayern to reach semi-finals',
#    'description': 'For Manchester City to sail so serenely past the six-times European champions shows how far Pep Guardiola has already taken them. The big question now is can they go all the way and finally seal the glory of a first Champions League triumph.Next up is a semi-…',
#    'url': 'https://www.theguardian.com/football/2023/apr/19/haaland-on-target-as-manchester-city-ease-past-bayern-to-reach-semi-finals',
#    'urlToImage': 'https://i.guim.co.uk/img/media/1716ec2c80491872ef46a15212ad894e0238b49b/0_33_3500_2101/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=5f708dd5ac960d0bcae2c74f40ca9a74',
#    'publishedAt': '2023-04-19T21:04:11Z',
#    'content': 'For Manchester City to sail so serenely past the six-times European champions shows how far Pep Guardiola has already taken them. The big question now is can they go all the way and finally seal the … [+5119 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Stephen Burgen in Barcelona',
#    'title': 'Suspended in time: inside Barcelona’s civil war air-raid shelters',
#    'description': 'Exhibition brings together new photographs of 40 of the more than 1,000 shelters built during conflictIn 1937, at the height of the Spanish civil war, Barcelona’s citizens hurriedly began the construction of air-raid shelters in anticipation of the bombardmen…',
#    'url': 'https://www.theguardian.com/world/2023/apr/16/inside-barcelona-spanish-civil-war-air-raid-shelters',
#    'urlToImage': 'https://i.guim.co.uk/img/media/540a3f999ddab8ada29f9a0b3751cb689918184e/0_293_6000_3602/master/6000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=a483bcdfa70ed4216adaaa73a184b947',
#    'publishedAt': '2023-04-16T07:00:04Z',
#    'content': 'In 1937, at the height of the Spanish civil war, Barcelonas citizens hurriedly began the construction of air-raid shelters in anticipation of the bombardment that had already been unleashed on Madrid… [+3301 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Sid Lowe',
#    'title': 'Samuel Chukwueze’s cartoon golazo seals his place as Villarreal’s new hero | Sid Lowe',
#    'description': 'The Nigerian winger was unstoppable against Real Madrid and is approaching his peak after a long, hard journey to SpainHis boots are on fire, and not for the first time. When Samuel Chimerenka Chukwueze was a boy growing up in Umahia, southeast Nigeria, all h…',
#    'url': 'https://www.theguardian.com/football/2023/apr/10/samuel-chukwuezes-cartoon-golazo-seals-his-place-as-villarreals-new-hero',
#    'urlToImage': 'https://i.guim.co.uk/img/media/5ecd9c26b48df9b7d6bb8904e349da299619a012/0_201_5000_3001/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=710314fb7a443183c7a0cd50d952200b',
#    'publishedAt': '2023-04-10T15:37:19Z',
#    'content': 'His boots are on fire, and not for the first time. When Samuel Chimerenka Chukwueze was a boy growing up in Umahia, southeast Nigeria, all he wanted to do was play football but his mum had other idea… [+9259 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Guardian Staff',
#    'title': 'Milan against the world: five of their greatest nights on the big stage',
#    'description': 'As Milan prepare for a Champions League quarter-final, we remember some of the best performances in their historyBy Henry Bell for The Gentleman UltraIf Real Madrid are the undisputed kings of Europe, Milan must be the princes. They are streets ahead of other…',
#    'url': 'https://www.theguardian.com/football/the-gentleman-ultra/2023/apr/12/milan-world-greatest-nights-champions-league-quarter-final-history',
#    'urlToImage': 'https://i.guim.co.uk/img/media/38b39053d185c2c6d7308444d0ff8fb09d16e778/0_0_5000_3000/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=068bc03d58544885ed7aa2d19caf6798',
#    'publishedAt': '2023-04-12T11:12:51Z',
#    'content': 'If Real Madrid are the undisputed kings of Europe, Milan must be the princes. They are streets ahead of other Italian clubs when it comes to winning continental trophies: seven European Cups, two Cup… [+8847 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Amazon closing UK-based online shop Book Depository',
#    'description': 'The announcement was met with sadness by many of its customers from around the world.',
#    'url': 'https://www.bbc.co.uk/news/business-65184776',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/15169/production/_129277368_bookdepository.jpg',
#    'publishedAt': '2023-04-05T04:38:48Z',
#    'content': 'UK-based online store Book Depository is being closed down by its parent company, the US technology giant Amazon.\r\nBook Depository has told customers it will cease operations later this month after a… [+2209 chars]'},
#   {'source': {'id': None, 'name': 'ESPN'},
#    'author': 'Gab Marcotti',
# ...
#    'publishedAt': '2023-04-20T11:19:19Z',
#    'content': 'Le joueur de tennis espagnol Rafael Nadal, au Masters 1000\xa0de Madrid, le 5\xa0mai 2022. MANU FERNANDEZ / AP\r\nLe rétablissement de Rafael Nadal prendra bien plus de temps que prévu. Le joueur de tennis e… [+2802 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Jody Serrano and Matías S. Zavia',
#    'title': "Gerard Piqué’s Twitch Soccer League Crowns 'El Barrio' Champion Before 92,500 People",
#    'description': 'BARCELONA, Spain — Gerard Piqué’s Kings League, a new soccer league that just three months ago debuted to jokes and scorn, came to a glorious, dramatic finish in FC Barcelona’s famous Camp Nou stadium on Sunday. As Piqué handed the glittering gold trophy to t…',
#    'url': 'https://gizmodo.com/pique-kings-league-camp-nou-final-contreras-el-barrio-1850267466',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/de5764d2c60fa84c6d959e19051e5c8b.jpg',
#    'publishedAt': '2023-03-27T03:50:00Z',
#    'content': 'BARCELONA, Spain Gerard Piqués Kings League, a new soccer league that just three months ago debuted to jokes and scorn, came to a glorious, dramatic finish in FC Barcelonas famous Camp Nou stadium on… [+5304 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Will Unwin at Molineux',
#    'title': 'Frank Lampard warns Chelsea: ‘Without aggression you can’t win games’',
#    'description': '<ul><li>Blues urged to show more desire after 1-0 defeat by Wolves</li><li>‘We need more aggression, more speed, more competitive duels’</li></ul>Frank Lampard has called on his Chelsea players to be more aggressive after a sluggish start to his second spell …',
#    'url': 'https://www.theguardian.com/football/2023/apr/08/frank-lampard-warns-chelsea-without-aggression-you-cant-win-games',
#    'urlToImage': 'https://i.guim.co.uk/img/media/a6137f13f7d068c92910b88b8b09f4299012a708/0_238_5438_3262/master/5438.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=a0aa72c8b0601a3d64ae5ad2957f992b',
#    'publishedAt': '2023-04-08T20:26:07Z',
#    'content': 'Frank Lampard has called on his Chelsea players to be more aggressive after a sluggish start to his second spell in charge. The visitors struggled to cope with Wolves in their 1-0 loss at Molineux on… [+3770 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Will Unwin',
#    'title': 'Milan v Napoli: Champions League quarter-final, first leg – live',
#    'description': '<ul><li>Champions League updates from the 8pm BST kick-off</li><li>Real Madrid v Chelsea | Email Will or tweet @Will_Unwin</li></ul>It is fourth against first in Serie A, although that does not count for much in Europe. After Internazionale’s win at Benfica l…',
#    'url': 'https://www.theguardian.com/football/live/2023/apr/12/milan-v-napoli-champions-league-quarter-final-first-leg-live-score-updates',
#    'urlToImage': 'https://i.guim.co.uk/img/media/670d72020b4b74329fd0f7fde24c72ebef8e1c83/0_284_5568_3341/master/5568.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=478e7d8c36c832211b3d815427e551c5',
#    'publishedAt': '2023-04-12T17:52:26Z',
#    'content': 'Stefano Pioli is confident in his own look.\r\nStefano Pioli patrols the touchline. Photograph: Gabriel Bouys/AFP/Getty Images\r\nStarting lineups\r\nMilan (4-3-3): Maignan; Calabria, Kjaer, Tomori, Theo H… [+1827 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Karen Carney',
#    'title': 'Rodri’s Manchester City role shows holding midfielders are key to success | Karen Carney',
#    'description': 'Manchester City and Arsenal’s title battle – and Liverpool’s recent struggles – show that a solid midfield is crucialThe holding midfield role is a bespoke one; you need to be technically very good, not just a destroyer, have a high-level understanding of the…',
#    'url': 'https://www.theguardian.com/football/blog/2023/mar/30/rodri-indispensable-manchester-city-hunt-for-trophies-holding-midfielders',
#    'urlToImage': 'https://i.guim.co.uk/img/media/6f1afc6c689ae1168ecd97149282ab6d4f06cd9b/0_304_5478_3287/master/5478.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctb3BpbmlvbnMucG5n&enable=upscale&s=c0b82a741f65636d25f14858ac047bdf',
#    'publishedAt': '2023-03-30T15:00:01Z',
#    'content': 'The holding midfield role is a bespoke one; you need to be technically very good, not just a destroyer, have a high-level understanding of the game and be able to drop into the backline but also brea… [+5120 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Claire Jones and Nicholas Lee (Metdesk)',
#    'title': 'Weather tracker: Spain edges towards record March heat',
#    'description': 'High of 31.9C reached in Murcia this week, with temperatures expected to rise until FridayIt has been hot across south-eastern parts of Spain this weekend with temperatures reaching the high-20s Celsius. Murcia reached 31.9C and Alicante reached 30.8C on Sund…',
#    'url': 'https://www.theguardian.com/environment/2023/mar/27/weather-tracker-spain-edges-towards-record-march-heat',
#    'urlToImage': 'https://i.guim.co.uk/img/media/6eb92a325c72f6cfb071e87002cf8acc32004efc/0_63_5000_3001/master/5000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=4024312b69d89e7fe5e880c3fec1a056',
#    'publishedAt': '2023-03-27T11:33:03Z',
#    'content': 'It has been hot across south-eastern parts of Spain this weekend with temperatures reaching the high-20s Celsius. Murcia reached 31.9C and Alicante 30.8C on Sunday. This was close to the March record… [+2051 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jamie Jackson in Munich',
#    'title': 'Pep Guardiola calls on Manchester City to ‘punish’ Bayern Munich in second leg',
#    'description': '<ul><li>Premier League champions hold 3-0 advantage from first leg</li><li>Manager tells players to forget previous Champions League exits</li></ul>Pep Guardiola has urged Manchester City not to dwell on previous Champions League exits and to try to “punish” …',
#    'url': 'https://www.theguardian.com/football/2023/apr/18/pep-guardiola-calls-on-manchester-city-to-punish-bayern-munich',
#    'urlToImage': 'https://i.guim.co.uk/img/media/df5f3c95d580bcea42fcccc8bdd98cb4fdb9e8dc/0_151_2687_1612/master/2687.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=7cbefc6e183b9b499a097bba567894ce',
#    'publishedAt': '2023-04-18T19:12:57Z',
#    'content': 'Pep Guardiola has urged Manchester City not to dwell on previous Champions League exits and to try to punish Bayern Munich in the quarter-final second leg on Wednesday despite their 3-0 advantage.\r\nC… [+4326 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jamie Jackson at Wembley',
#    'title': '‘We are neighbours’: Guardiola laughs off Manchester United fans’ treble fears',
#    'description': '<ul><li>City could feasibly emulate their rivals’ 1999 trophy haul</li><li>Rivals will meet in FA Cup final if United beat Brighton</li></ul>Pep Guardiola joked that Manchester United fans should not be scared of Manchester City emulating their team by claimi…',
#    'url': 'https://www.theguardian.com/football/2023/apr/22/we-are-neighbours-guardiola-laughs-off-manchester-united-fans-treble-fears',
#    'urlToImage': 'https://i.guim.co.uk/img/media/baa0690c614cc0fc68ee002294f529227e3881bb/160_14_1316_789/master/1316.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=b658127bb935afcb0b90a846a5e390c6',
#    'publishedAt': '2023-04-22T19:48:20Z',
#    'content': 'Pep Guardiola joked that Manchester United fans should not be scared of Manchester City emulating their team by claiming the treble because of their neighbourly spirit.\r\nThe champions beat Sheffield … [+2841 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Associated Press',
#    'title': 'Greek club Olympiakos releases James Rodríguez',
#    'description': 'Colombian attacking midfielder James Rodríguez was released by Olympiakos on Thursday, a day after the club was knocked out of the Greek Cup.  The 31-year...',
#    'url': 'https://news.yahoo.com/greek-club-olympiakos-releases-james-165054155.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/1IYH1Ue3hvpQd0804XARPA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03NjY-/https://media.zenfs.com/en/ap.org/e0ffd2c13578a0d8277b3516b04a8690',
#    'publishedAt': '2023-04-13T16:50:54Z',
#    'content': 'PIRAEUS, Greece (AP) Colombian attacking midfielder James Rodríguez was released by Olympiakos on Thursday, a day after the club was knocked out of the Greek Cup.\r\nThe 31-year-old former Real Madrid … [+612 chars]'},
#   {'source': {'id': None, 'name': 'ESPN'},
#    'author': 'Sam Marsden',
#    'title': "Barca miss Pedri's creativity, overlook Fati in draw vs. Getafe",
#    'description': 'Despite being title favorites, Barcelona are staggering their way to the finish line in LaLiga after their second consecutive goalless draw.',
#    'url': 'https://www.espn.com/soccer/spanish-laliga/story/4925856/barcelona-miss-pedris-creativity-overlook-fati-after-dropping-points-again',
#    'urlToImage': 'https://a.espncdn.com/combiner/i?img=%2Fphoto%2F2023%2F0416%2Fr1159632_1296x729_16%2D9.jpg',
#    'publishedAt': '2023-04-16T17:05:11Z',
#    'content': "Barcelona were held to a goalless draw at Getafe on Sunday as their winless run in all competitions stretched to three games.\r\nXavi Hernandez's side remain 11 points clear of Real Madrid at the top o… [+6726 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'michael.hicks@futurenet.com (Michael L Hicks)',
#    'title': 'How to use Google Maps Live View features',
#    'description': 'Live View has come a long way in the past few years, adding new tricks like calibrating your location and getting directions in indoor locations like malls and airports.',
#    'url': 'https://www.androidcentral.com/apps-software/google-maps/how-to-use-google-maps-live-view-features',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/sfgj29zfyaTZUqfSBqSeVf-1200-80.jpeg',
#    'publishedAt': '2023-04-09T15:45:52Z',
#    'content': 'Google Maps Live View uses augmented reality to help make walking directions more accessible and dynamic on both Android phones and iPhones. Once you know where to find it, Live View is relatively ea… [+5626 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Will Unwin at Molineux',
#    'title': 'Frank Lampard suffers on Chelsea return as Nunes snatches Wolves win',
#    'description': 'Chelsea transitioned seamlessly from the Graham Potter era to the second coming of Frank Lampard with defeat at Wolves. Bar a few tactical tweaks and personnel changes, it was the same meek and tired team that has plodded its way to mid-table mediocrity.Even …',
#    'url': 'https://www.theguardian.com/football/2023/apr/08/wolves-chelsea-premier-league-match-report',
#    'urlToImage': 'https://i.guim.co.uk/img/media/24bd03eee0d0c8f5b50c80bd5f23e42bed1b77e7/76_246_2924_1754/master/2924.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=45740c0a3dba6dafa4e5af89d05312a2',
#    'publishedAt': '2023-04-08T16:04:25Z',
#    'content': 'Chelsea transitioned seamlessly from the Graham Potter era to the second coming of Frank Lampard with defeat at Wolves. Bar a few tactical tweaks and personnel changes, it was the same meek and tired… [+5261 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Jacob Steinberg',
#    'title': 'Chelsea to hold talks with Luis Enrique while Lampard return considered',
#    'description': '<ul><li>Luis Enrique is in London after impressing in discussions</li><li>Lampard prepared to be head coach on short-term basis</li></ul>Chelsea are preparing to hold talks with Luis Enrique, who is vying with Julian Nagelsmann for the manager’s job, but have…',
#    'url': 'https://www.theguardian.com/football/2023/apr/05/chelsea-to-hold-talks-luis-enrique-manager-frank-lampard-return-considered',
#    'urlToImage': 'https://i.guim.co.uk/img/media/386dd2c23f0f6478acbe605f423e197f3e69604e/481_181_2980_1788/master/2980.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=1573313362e8bd546bb2f9e398e0dd9e',
#    'publishedAt': '2023-04-05T14:51:06Z',
#    'content': 'Chelsea are preparing to hold talks with Luis Enrique, who is vying with Julian Nagelsmann for the managers job, but have not ruled out making Frank Lampard interim coach if they cannot convince one … [+3911 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Barry Glendenning',
#    'title': 'Football Daily | Frank Lampard and another case of the Blues',
#    'description': 'Sign up now! Sign up now! Sign up now? Sign up now!Hearing Todd Boehly talk as he emerged from the pre-match lunch hosted by Real Madrid dignitaries for their Chelsea counterparts in the Spanish capital on Wednesday, you could have been forgiven for thinking …',
#    'url': 'https://www.theguardian.com/football/2023/apr/13/chelsea-frank-lampard-todd-boehly-big-cup',
#    'urlToImage': 'https://i.guim.co.uk/img/media/51f2ba5be811319260d671c5fd9164ebf69fe50b/0_171_3419_2053/master/3419.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=7652fb24bba7a363faf880e4d46a3988',
#    'publishedAt': '2023-04-13T14:34:10Z',
#    'content': 'WILL IT BE ANOTHER BRIDGE TOO FAR?\r\nHearing Todd Boehly talk as he emerged from the pre-match lunch hosted by Real Madrid dignitaries for their Chelsea counterparts in the Spanish capital on Wednesda… [+4332 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Guardian sport',
#    'title': 'Frank Lampard confirmed as Chelsea caretaker manager until end of season',
#    'description': '<ul><li>Lampard returns to post he held between 2019 and 2021</li><li>Club seek long-term manager, Luis Enrique leading the list</li></ul>Frank Lampard has returned to Chelsea to serve as caretaker manager until the end of the season.The club’s record goalsco…',
#    'url': 'https://www.theguardian.com/football/2023/apr/06/frank-lampard-confirmed-as-chelsea-caretaker-manager-until-end-of-season',
#    'urlToImage': 'https://i.guim.co.uk/img/media/c1868483e52bbb4b5f14354185de513dfa7161d6/192_21_3084_1851/master/3084.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=ab35f03588f4bd56846d8d7229aec310',
#    'publishedAt': '2023-04-06T12:30:05Z',
#    'content': 'Frank Lampard has returned to Chelsea to serve as caretaker manager until the end of the season. The clubs record goalscorer and full-time manager between 2019 and 2021 will be in place while the own… [+2272 chars]'}]}

# %%
WEATHER_API_KEY = '8831d413bb40311275e912234c1df8cb'
GEOCODE_API_KEY = '205787102155036129079x23712 '

def get_forward_geocoding(address):
    q = parse.quote(address)
    geocode_url = f'https://geocode.xyz/{q}?geoit=JSON&auth={GEOCODE_API_KEY}'
    res = requests.get(geocode_url)
    return json.loads(res.content.decode())

def get_reverse_geocoding(lat, lon):
    geocode_url=f'https://geocode.xyz/{lat},{lon}?geoit=JSON&auth={GEOCODE_API_KEY}'
    res = requests.get(geocode_url)
    return json.loads(res.content.decode())

def get_weather(lat, lon):
    weather_url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={WEATHER_API_KEY}'
    res = requests.get(weather_url)
    return json.loads(res.content.decode())

# %%
get_forward_geocoding(address="Calle Tres Peces 26, Madrid, Spain")
# Out:
# {'standard': {'stnumber': '25',
#   'addresst': 'Tres Peces',
#   'statename': 'Comunidad de Madrid',
#   'postal': '28012',
#   'region': 'Comunidad de Madrid',
#   'city': 'Madrid',
#   'prov': 'ES',
#   'countryname': 'Spain',
#   'confidence': '0.9'},
#  'longt': '-3.69883',
#  'alt': {},
#  'elevation': {},
#  'remaining_credits': '-1',
#  'latt': '40.41099'}

# %%
get_reverse_geocoding(lat=40.41099, lon=-3.69883)
# Out:
# {'statename': {},
#  'distance': '0.000',
#  'elevation': '647',
#  'osmtags': {'wikipedia': 'es:Embajadores (Madrid)',
#   'wikidata': 'Q2449844',
#   'boundary': 'administrative',
#   'name': 'Embajadores',
#   'type': 'boundary',
#   'landuse': 'residential',
#   'admin_level': '10'},
#  'state': 'Comunidad de Madrid',
#  'latt': '40.41099',
#  'city': 'Madrid',
#  'prov': 'ES',
#  'intersection': {'distance': '0.099',
#   'xlat': '40.4101008',
#   'xlon': '-3.69876075',
#   'street2': 'BUENAVISTA',
#   'street1': 'CL ZURITA'},
#  'geocode': 'MADRID-KVUZC',
#  'geonumber': '3162553972580',
#  'country': 'Spain',
#  'stnumber': '25',
#  'staddress': 'CL TRES PECES',
#  'inlatt': '40.41099',
#  'alt': {'loc': [{'staddress': 'CL TRES PECES',
#     'stnumber': '25',
#     'postal': '28012',
#     'latt': '40.41099',
#     'city': 'Madrid',
#     'prov': 'Comunidad de Madrid',
#     'longt': '-3.69883',
#     'class': {}},
#    {'staddress': 'TRES PECES',
#     'stnumber': '25',
#     'postal': {},
#     'latt': '40.41099',
#     'city': 'Comunidad de Madrid',
#     'prov': 'Comunidad de Madrid',
#     'longt': '-3.69883',
#     'class': {}},
#    {'staddress': 'Calle de los Tres Peces',
#     'stnumber': '25',
#     'postal': '28012',
#     'latt': '40.41099',
#     'city': 'Madrid',
#     'prov': 'Comunidad de Madrid',
#     'longt': '-3.69883',
#     'class': {}},
#    {'staddress': 'CL TRES PECES',
#     'stnumber': '25',
#     'postal': '28012',
#     'latt': '40.41099',
#     'city': 'Comunidad de Madrid',
#     'prov': 'Comunidad de Madrid',
#     'longt': '-3.69883',
#     'class': {}},
#    {'staddress': 'Tres Peces',
#     'stnumber': '25',
#     'postal': {},
#     'latt': '40.41099',
#     'city': 'Madrid',
#     'prov': 'Comunidad de Madrid',
#     'longt': '-3.69883',
#     'class': {}}]},
#  'timezone': 'Europe/Madrid',
#  'region': 'Madrid, Comunidad de Madrid',
#  'postal': '28012',
#  'poi': {'poilat': '40.41112',
#   'wheelchair': 'limited',
#   'name': 'Bar el Hórreo',
#   'addr_street': 'Calle de Santa Isabel',
#   'addr_postcode': '28012',
#   'amenity': 'bar',
#   'poilon': '-3.69868',
#   'addr_city': 'Madrid',
#   'id': '2546777610',
#   'poidist': '0.019'},
#  'longt': '-3.69883',
#  'remaining_credits': '-2',
#  'confidence': '1',
#  'inlongt': '-3.69883',
#  'class': {},
#  'adminareas': {'admin10': {'wikipedia': 'es:Embajadores (Madrid)',
#    'wikidata': 'Q2449844',
#    'name': 'Embajadores',
#    'admin_level': '10',
#    'level': '10',
#    'boundary': 'administrative',
#    'type': 'boundary',
#    'landuse': 'residential'},
#   'admin7': {'wikipedia': 'es:Área Metropolitana de Madrid',
#    'wikidata': 'Q959356',
#    'is_in': 'Comunidad de Madrid;Spain;Europe',
#    'is_in_region': 'Comunidad de Madrid',
#    'name': 'Área metropolitana de Madrid y Corredor del Henares',
#    'is_in_province_code': '28',
#    'is_in_country': 'Spain',
#    'admin_level': '7',
#    'level': '7',
#    'boundary': 'administrative',
#    'type': 'boundary',
#    'name_el': 'Μητροπολιτική περιοχή της Μαδρίτης'},
#   'admin6': {'wikipedia': 'es:Comarcas de la Comunidad de Madrid',
#    'source': 'BDLL25, EGRN, Instituto Geográfico Nacional',
#    'name_de': 'Autonome Gemeinschaft Madrid',
#    'idee_name': 'Madrid, Comunidad de',
#    'name_pt': 'Comunidade de Madrid',
#    'is_in_region': 'Comunidad de Madrid',
#    'is_in_country_code': 'ES',
#    'name_ru': 'Мадрид',
#    'name_be': 'Мадрыд',
#    'official_name_es': 'Comunidad de Madrid',
#    'boundary': 'administrative',
#    'name_en': 'Community of Madrid',
#    'is_in_continent': 'Europe',
#    'is_in_region_code': '13',
#    'is_in': 'Europe;Spain;Comunidad de Madrid',
#    'name': 'Comunidad de Madrid',
#    'ISO3166_2': 'ES-M',
#    'official_name': 'Comunidad de Madrid',
#    'name_es': 'Comunidad de Madrid',
#    'name_ca': 'Comunitat de Madrid',
#    'is_in_country': 'Spain',
#    'admin_level': '6',
#    'ine_provincia': '28',
#    'name_pl': 'Wspólnota Madrytu',
#    'level': '6',
#    'type': 'boundary',
#    'name_fr': 'Communauté de Madrid',
#    'border_type': 'province'},
#   'admin9': {'wikipedia': 'es:Centro (Madrid)',
#    'wikidata': 'Q1763376',
#    'is_in_continent': 'Europe',
#    'is_in': 'Madrid, Comunidad de Madrid, España',
#    'is_in_region': 'Madrid',
#    'name': 'Centro',
#    'is_in_country': 'España',
#    'is_in_province': 'Madrid',
#    'admin_level': '9',
#    'level': '9',
#    'boundary': 'administrative',
#    'type': 'boundary'},
#   'admin8': {'wikipedia': 'es:Madrid',
#    'population': '3233527',
#    'ine_municipio': '28079',
#    'is_in_region': 'Comunidad de Madrid',
#    'name_ru': 'Мадрид',
#    'is_in_province': 'Madrid',
#    'boundary': 'administrative',
#    'name_ko': '마드리드',
#    'name_en': 'Madrid',
#    'name_el': 'Μαδρίτη',
#    'name_cs': 'Madrid',
#    'wikidata': 'Q2807',
#    'is_in': 'Madrid;Comunidad de Madrid;Spain;Europe',
#    'name': 'Madrid',
#    'name_es': 'Madrid',
#    'addr_postcode': '28001',
#    'is_in_country': 'Spain',
#    'admin_level': '8',
#    'level': '8',
#    'type': 'boundary'}},
#  'altgeocode': 'EMBAES-KVUZC'}

# %%
get_weather(lat=40.41099, lon=-3.69883)
# Out:
# {'coord': {'lon': -3.6988, 'lat': 40.411},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 299.23,
#   'feels_like': 299.23,
#   'temp_min': 297.66,
#   'temp_max': 301.17,
#   'pressure': 1017,
#   'humidity': 27},
#  'visibility': 10000,
#  'wind': {'speed': 1.34, 'deg': 179, 'gust': 3.58},
#  'clouds': {'all': 0},
#  'dt': 1682594291,
#  'sys': {'type': 2,
#   'id': 2007545,
#   'country': 'ES',
#   'sunrise': 1682572781,
#   'sunset': 1682622301},
#  'timezone': 7200,
#  'id': 3117735,
#  'name': 'Madrid',
#  'cod': 200}
